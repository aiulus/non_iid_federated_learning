# %%
import experiments.mnist_experiment as data
from torchvision import datasets
from keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 import experiments.mnist_experiment as data
#       2 from torchvision import datasets
#       3 from keras.preprocessing.image import ImageDataGenerator
#
# ModuleNotFoundError: No module named 'experiments'

# %%
x_train, y_train, x_test, y_test = data.get_data("C:/Users/Aybüke/PycharmProjects/datasets")
subset_IDs = data.partition("C:/Users/Aybüke/PycharmProjects/datasets", "hetero-dir", 10, 0.5)

x_subsets = [x_train[subset_IDs.get(key)] for key in range(len(subset_IDs))]
y_subsets = [y_train[subset_IDs.get(key)] for key in range(len(subset_IDs))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 x_train, y_train, x_test, y_test = data.get_data("C:/Users/Aybüke/PycharmProjects/datasets")
#       2 subset_IDs = data.partition("C:/Users/Aybüke/PycharmProjects/datasets", "hetero-dir", 10, 0.5)
#       4 x_subsets = [x_train[subset_IDs.get(key)] for key in range(len(subset_IDs))]
#
# NameError: name 'data' is not defined

# %%
datagen = ImageDataGenerator(width_shift_range=0.25, height_shift_range=0.25)
datagen.fit(x_subsets[0].reshape(x_train[0].shape[0], 28, 28, 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 datagen = ImageDataGenerator(width_shift_range=0.25, height_shift_range=0.25)
#       2 datagen.fit(x_subsets[0].reshape(x_train[0].shape[0], 28, 28, 1))
#
# NameError: name 'ImageDataGenerator' is not defined
