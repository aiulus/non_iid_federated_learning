# %%
import graphviz, pydot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 import graphviz, pydot
#
# ModuleNotFoundError: No module named 'graphviz'

# %% [markdown]
# Create graph object:

# %%
dot = graphviz.Digraph(comment='The Round Table')

# %% [markdown]
# Add nodes and edges, check the generated source code:

# %%
dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

print(dot.source)

# %% [markdown]
# Save and render the source code:

# %%
doctest_mark_exe()
dot.render('doctest-output/round-table.gv').replace('\\', '/')

# %% [markdown]
# Save, render and view the result:

# %%
doctest_mark_exe()
dot.render('doctest-output/round-table.gv', view=True)
